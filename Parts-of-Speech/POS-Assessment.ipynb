# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>

# %%
# Enter your code here:

with open("peterrabbit.txt", "r") as txt:
    doc = nlp(txt.read())

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:

# getting sentences of doc
sentences = [sent for sent in doc.sents]

# 3rd sentence's tokens
for token in sentences[2]:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_):{10}}')
# Out:
# '          VERB       VBP        verb, non-3rd person singular present
# Now        ADV        RB         adverb
# my         PRON       PRP$       pronoun, possessive
# dears      NOUN       NNS        noun, plural
# ,          PUNCT      ,          punctuation mark, comma
# '          PUNCT      ''         closing quotation mark
# said       VERB       VBD        verb, past tense
# old        ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# Mrs.       PROPN      NNP        noun, proper singular
# Rabbit     PROPN      NNP        noun, proper singular
# one        NUM        CD         cardinal number
# morning    NOUN       NN         noun, singular or mass
# ,          PUNCT      ,          punctuation mark, comma
# '          PUNCT      ``         opening quotation mark
# you        PRON       PRP        pronoun, personal
# may        AUX        MD         verb, modal auxiliary
# go         VERB       VB         verb, base form
# into       ADP        IN         conjunction, subordinating or preposition
#
#           SPACE      _SP        whitespace
# the        DET        DT         determiner
# fields     NOUN       NNS        noun, plural
# or         CCONJ      CC         conjunction, coordinating
# down       ADP        IN         conjunction, subordinating or preposition
# the        DET        DT         determiner
# lane       NOUN       NN         noun, singular or mass
# ,          PUNCT      ,          punctuation mark, comma
# but        CCONJ      CC         conjunction, coordinating
# do         AUX        VBP        verb, non-3rd person singular present
# n't        PART       RB         adverb
# go         VERB       VB         verb, base form
# into       ADP        IN         conjunction, subordinating or preposition
# Mr.        PROPN      NNP        noun, proper singular
# McGregor   PROPN      NNP        noun, proper singular
# 's         PART       POS        possessive ending
# garden     NOUN       NN         noun, singular or mass
# :          PUNCT      :          punctuation mark, colon or ellipsis
#
#           SPACE      _SP        whitespace
# your       PRON       PRP$       pronoun, possessive
# Father     PROPN      NNP        noun, proper singular
# had        VERB       VBD        verb, past tense
# an         DET        DT         determiner
# accident   NOUN       NN         noun, singular or mass
# there      ADV        RB         adverb
# ;          PUNCT      :          punctuation mark, colon or ellipsis
# he         PRON       PRP        pronoun, personal
# was        AUX        VBD        verb, past tense
# put        VERB       VBN        verb, past participle
# in         ADP        IN         conjunction, subordinating or preposition
# a          DET        DT         determiner
# pie        NOUN       NN         noun, singular or mass
# by         ADP        IN         conjunction, subordinating or preposition
# Mrs.       PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
# McGregor   PROPN      NNP        noun, proper singular
# .          PUNCT      .          punctuation mark, sentence closer
# '          PUNCT      ''         closing quotation mark
#
#
#          SPACE      _SP        whitespace

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
# Enter your code here:

# returning integers that map to different parts of speech
counts_dict = doc.count_by(spacy.attrs.IDS['POS'])

# printing part of speech tags
for pos, count in counts_dict.items():
    tag_name = doc.vocab[pos].text
    print(f'{pos:{5}} {tag_name:{8}} {count}')
# Out:
#    86 ADV      111
#    98 SCONJ    80
#    90 DET      432
#    92 NOUN     833
#    95 PRON     259
#   100 VERB     493
#    93 NUM      45
#    84 ADJ      240
#    97 PUNCT    550
#    89 CCONJ    205
#   103 SPACE    420
#    96 PROPN    485
#    85 ADP      520
#    87 AUX      177
#    94 PART     100
#   101 X        55
#    99 SYM      6
#    91 INTJ     2

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
# note in my case NOUN is under 92

percent_of_noun = (counts_dict[92] * 100)/ len(doc)
percent_of_noun
# Out:
# 16.616796329543188

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
 displacy.render(sentences[2], style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ba164a1e28314b92b8e3ad374d4dcb59-0" class="displacy" width="5810" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">dears,'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">old</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Rabbit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">morning, '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">down</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">lane,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">McGregor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">garden:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">SPACE</tspan>
# </text>

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's The Tale of Peter Rabbit**

# %%
print(f'{doc.ents[0]}, {doc.ents[0].label_}, {spacy.explain(doc.ents[0].label_)}', "\n")
print(f'{doc.ents[1]}, {doc.ents[1].label_}, {spacy.explain(doc.ents[1].label_)}')
# Out:
# four, CARDINAL, Numerals that do not fall under another type
#
# were--
#
#           Flopsy, ORG, Companies, agencies, institutions, etc.

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(sentences)
# Out:
# 177

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
num_of_ner_sents = 0

for sent in sentences:
    if sent.ents != []:
        num_of_ner_sents += 1
    
num_of_ner_sents
# Out:
# 123

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(sentences[0], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Once upon a time there were
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  little Rabbits, and their names</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     were--
#
#           Flopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cotton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -tail,</br>and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br></br></div></span>
